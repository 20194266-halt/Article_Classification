# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# unrar file Test.rar
# !unrar x -y "/content/drive/MyDrive/ML/Test.rar" "/content/drive/MyDrive/ML/"

# %%
# unrar file Train.rar
# !unrar x -y "/content/drive/MyDrive/ML/Train.rar" "/content/drive/MyDrive/ML/"
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# Cài đặt thư viện underthesea
# !pip install underthesea
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.0 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 58.1 MB/s
# ...
#      |████████████████████████████████| 591 kB 40.0 MB/s
# ...

# %%
# Cài đặt thư viện tqdm
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from underthesea import word_tokenize
from tqdm import tqdm
import numpy as np
import gensim
import os

# %%
from underthesea import word_tokenize
sentence = 'Trường đại học bách khoa hà nội'
word_tokenize(sentence, format="text")
# Out:
# 'Trường đại_học bách_khoa hà_nội'

# %%
# Cài đặt thư viện pyvi
# !pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.5 MB 4.8 MB/s
# ...

# %%
from pyvi import ViTokenizer
ViTokenizer.tokenize(u"Trường đại học bách khoa hà nội")
# Out:
# 'Trường đại_học bách_khoa hà_nội'

# %%
# Hàm tách từ
# Tham số: folder_path - Đường dẫn đến folder chứa các file cần tách từ
def get_data(folder_path):
    X = []
    y = []
    dirs = os.listdir(folder_path)
    for path in tqdm(dirs):
        file_paths = os.listdir(os.path.join(folder_path, path))
        for file_path in tqdm(file_paths):
            with open(os.path.join(folder_path, path, file_path), 'r', encoding="utf-16") as f:
                lines = f.readlines()
                lines = ' '.join(lines)
                lines = gensim.utils.simple_preprocess(lines)
                lines = ' '.join(lines)
                lines = word_tokenize(lines, format="text")
                #lines = ViTokenizer.tokenize(lines)
                X.append(lines)
                y.append(path)

    return X, y

# %%
# Thực hiện tách từ đối với tập train
X_data, y_data = get_data('/content/drive/MyDrive/ML/new train')
# Out:
# ...
#  39%|███▊      | 227/588 [00:15<00:12, 29.62it/s]
# ...
# ...
# 100%|██████████| 27/27 [13:14<00:00, 29.42s/it]

# %%
# Lưu tập train đã tách từ vào file .pkl
import pickle

pickle.dump(X_data, open('/content/drive/MyDrive/ML/X_data.pkl', 'wb'))
pickle.dump(y_data, open('/content/drive/MyDrive/ML/y_data.pkl', 'wb'))

# %%
X_data[0]
# Out:
# 'phan đinh tùng không cho mình điểm dừng tôi rất tích_cực sáng_tác nếu có người hỗ_trợ tôi còn ra cd nhiều hơn mọi người thường quan_niệm số_lượng không đi cùng chất_lượng nhưng điều này hãy để thị_trường trả_lời còn tôi không cho mình điểm dừng vì thấy mình đang hưng_phấn đầy sức trẻ ca_sĩ tâm_sự dựa vào điều gì anh khẳng_định mtv đã phát_triển đến đỉnh_cao nhất rồi và không_thể tiến xa hơn được nữa không phải riêng tôi mà giới chuyên_môn cả nhạc_sĩ tuấn khanh và chính các thành_viên cũng công_nhận điều đó khi chưa tách ra solo mtv đã hoạt_động kiểu cầm_chừng_như một cỗ máy kiếm tiền không còn phát_triển chuyên_môn mọi người cảm_thấy ngao_ngán những mẫu thuẫn bắt_đầu nảy_sinh tôi đã đề_xuất làm live show cuỗi cùng để chấm_dứt sự hoạt_động của nhóm để đọng lại cho khán_giả những ấn_tượng tốt_đẹp rôi sau đó ai thích thì tiếp_tục hát solo mọi người đã đồng trong sự buồn_bã dẫu_sao mtv cũng được đánh_giá là nhóm nhạc số việt_nam thời_điểm bấy_giờ khi chưa tách khỏi mtv anh đã rục_rịch r
# ...

# %%
y_data[0]
# Out:
# 'Am nhac'

# %%
# Thực hiện tách từ đối với tập test
X_test, y_test = get_data('/content/drive/MyDrive/ML/new test')
# Out:
# ...
#  19%|█▊        | 137/735 [00:01<00:07, 83.47it/s]
# ...
# ...
# 100%|██████████| 27/27 [02:43<00:00,  6.05s/it]

# %%
# Lưu tập test đã tách từ vào file .pkl
pickle.dump(X_test, open('/content/drive/MyDrive/ML/X_test.pkl', 'wb'))
pickle.dump(y_test, open('/content/drive/MyDrive/ML/y_test.pkl', 'wb'))
